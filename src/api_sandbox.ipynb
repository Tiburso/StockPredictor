# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import yfinance as yf
from datetime import date, timedelta, datetime

from helpers.plots import data_plot 

from api.api_cache import session
from tickers import TICKERS

# %%
end_date = date.today().strftime("%Y-%m-%d") #end date for our data retrieval will be current date
start_date = '1990-01-01' # Beginning date for our historical data retrieval

tickers = yf.Tickers(TICKERS, session=session) # Create a Tickers object with the tickers we want to retrieve data for
df = tickers.download(start=start_date, end=end_date) # Download the data for the tickers

df.tail() # Display the last 5 rows of the dataframe
# Out:
# [*********************100%%**********************]  2 of 2 completed
# Price            Close             Dividends             High              \
# Ticker            AAPL        MSFT      AAPL MSFT        AAPL        MSFT
# Date
# 2024-02-28  181.419998  407.720001       0.0  0.0  183.119995  409.299988
# 2024-02-29  180.750000  413.640015       0.0  0.0  182.570007  414.200012
# 2024-03-01  179.660004  415.500000       0.0  0.0  180.529999  415.869995
# 2024-03-04  175.100006  414.920013       0.0  0.0  176.899994  417.350006
# 2024-03-05  170.119995  402.649994       0.0  0.0  172.039993  414.250000
#
# Price              Low                    Open             Stock Splits       \
# Ticker            AAPL        MSFT        AAPL        MSFT         AAPL MSFT
# Date
# 2024-02-28  180.130005  405.320007  182.509995  408.179993          0.0  0.0
# 2024-02-29  179.529999  405.920013  181.270004  408.640015          0.0  0.0
# 2024-03-01  177.380005  410.880005  179.550003  411.269989          0.0  0.0
# 2024-03-04  173.789993  412.320007  176.149994  413.440002          0.0  0.0
# 2024-03-05  169.619995  400.640015  170.759995  413.959991          0.0  0.0
#
# Price          Volume
# Ticker           AAPL      MSFT
# Date
# 2024-02-28   48953900  13183100
# 2024-02-29  136682600  31947300
# 2024-03-01   73488000  17800300
# 2024-03-04   81510100  17596000
# 2024-03-05   94983800  26884000

# %%
msft = tickers.tickers["MSFT"] # Get the Microsoft stock from the Tickers object

# print(msft.history(period="1mo")) # Get the historical data for the Microsoft stock for the last month
# print(msft.info) # Get the information about the Microsoft stock
# print(msft.option_chain("2024-03-08")) # Get the option chain for the Microsoft stock

msft.news
# Out:
# [{'uuid': '4205eaa9-f620-3a0b-a81a-0e82c7c9fd0b',
#   'title': 'Magnificent Seven Stocks To Buy And Watch: Nvidia Hits Record High, Tesla Slides',
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/4205eaa9-f620-3a0b-a81a-0e82c7c9fd0b/magnificent-seven-stocks-to.html',
#   'providerPublishTime': 1709738022,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/IVY_jviTG_ue49k31izfew--~B/aD02MDA7dz0xMDY1O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/f287385a5f84c1d1e13191d4ae92d9fb',
#      'width': 1065,
#      'height': 600,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/EDUpiEmpjj.CUhr9H67TBQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/f287385a5f84c1d1e13191d4ae92d9fb',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['NVDA', 'AAPL', 'TSLA', 'META', 'MSFT']},
#  {'uuid': 'a5fc1cfc-a36b-30d8-a09b-9845a7ac851e',
#   'title': "1 Brilliant Strategy That Could Supercharge Microsoft's Artificial Intelligence (AI) Revenue",
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/a5fc1cfc-a36b-30d8-a09b-9845a7ac851e/1-brilliant-strategy-that.html',
#   'providerPublishTime': 1709734500,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/8XP2easjSJwneWLU5UjcoA--~B/aD05MzI7dz0xNDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/e92e9313739334b57fcbb92a6d33adf3',
#      'width': 1400,
#      'height': 932,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/T.fqWndqLlq2oIkaJGiX4Q--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/e92e9313739334b57fcbb92a6d33adf3',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT']},
#  {'uuid': 'fe112492-6912-3b06-ac1d-ea49130816aa',
#   'title': 'Q4 2024 CrowdStrike Holdings Inc Earnings Call',
#   'publisher': 'Thomson Reuters StreetEvents',
#   'link': 'https://finance.yahoo.com/news/q4-2024-crowdstrike-holdings-inc-133417024.html',
#   'providerPublishTime': 1709732057,
#   'type': 'STORY',
#   'relatedTickers': ['CRWD', 'PANW', 'MSFT']},
#  {'uuid': '30404fed-9764-3736-beef-68dc7fa786c0',
#   'title': 'OpenAI publishes Elon Musk’s emails. ‘We’re sad that it’s come to this’',
#   'publisher': 'CNN Business',
#   'link': 'https://finance.yahoo.com/m/30404fed-9764-3736-beef-68dc7fa786c0/openai-publishes-elon-musk%E2%80%99s.html',
#   'providerPublishTime': 1709731779,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/7knubZGTiFzFt41IKjGPDg--~B/aD01NDA7dz05NjA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/cnn_business_articles_218/09f736e601bd842edb3a713c56a04c43',
#      'width': 960,
#      'height': 540,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/nqYxSNnOfgtJVeSZJLU4Yg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/cnn_business_articles_218/09f736e601bd842edb3a713c56a04c43',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT']},
#  {'uuid': '6fa55a71-2a5c-3c7c-852c-8da7ea2d36ba',
#   'title': 'Best Stocks To Buy And Watch Now: Palantir Headlines 5 Top Tech Stocks For March',
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/6fa55a71-2a5c-3c7c-852c-8da7ea2d36ba/best-stocks-to-buy-and-watch.html',
#   'providerPublishTime': 1709727629,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/YT.cwQLk4qEhyB3Bo5nmvw--~B/aD01NjM7dz0xMDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/2c5e2f23a6ddb52972e092492f32a3c0',
#      'width': 1000,
#      'height': 563,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/GA7cp4_u3IS0F6Kabd.tkw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/2c5e2f23a6ddb52972e092492f32a3c0',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT']},
#  {'uuid': '9326b80d-3c6f-32d5-9af2-1462075d79ec',
#   'title': 'Stocks, Gold, and Bitcoin Pull Back From Record Highs, What It Means. And 5 Other Things to Know Before Markets Open.',
#   'publisher': 'Barrons.com',
#   'link': 'https://finance.yahoo.com/m/9326b80d-3c6f-32d5-9af2-1462075d79ec/stocks%2C-gold%2C-and-bitcoin.html',
#   'providerPublishTime': 1709725800,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/Uu.Vlu5uQsV9s9C8fAi_sg--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/Barrons.com/a7007c3c9480d8932e59461bcc319df2',
#      'width': 1280,
#      'height': 640,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/sKC4_OxNKkfLapgdnwdfzQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/Barrons.com/a7007c3c9480d8932e59461bcc319df2',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['TSLA', 'MSFT']},
#  {'uuid': 'c11629d3-5f12-3051-bc5f-4dc79339f8eb',
#   'title': 'Elon Musk Wanted OpenAI to Merge With Tesla, Altman Says',
#   'publisher': 'Barrons.com',
#   'link': 'https://finance.yahoo.com/m/c11629d3-5f12-3051-bc5f-4dc79339f8eb/elon-musk-wanted-openai-to.html',
#   'providerPublishTime': 1709725260,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/yAsw4wK5lMgYKTiaD4EmHA--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/Barrons.com/307c74e37acb134ae0ac578d81b5f637',
#      'width': 1280,
#      'height': 640,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/xJruHvMW.aD1GrVK1Nb71A--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/Barrons.com/307c74e37acb134ae0ac578d81b5f637',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['TSLA', 'MSFT']},
#  {'uuid': '164033de-c26c-397a-9987-7b595e4dd361',
#   'title': 'Should You Buy the Worst-Performing "Magnificent Seven" Stock of the Past Decade?',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/164033de-c26c-397a-9987-7b595e4dd361/should-you-buy-the.html',
#   'providerPublishTime': 1709723760,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/iQGVyB6O4_QnJxhsGHjsxg--~B/aD01NTg7dz03MjA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/motleyfool.com/30de47220846dcdab5d21c09e165d0c7',
#      'width': 720,
#      'height': 558,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/C8mpqS1JleMkb_uzXZIXSA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/30de47220846dcdab5d21c09e165d0c7',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['GOOG', 'MSFT']}]
